# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/Suhas/Downloads/nyc_weather.csv')
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
df.shape
# Out:
# (31, 11)

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df.EST
# Out:
# 0      1/1/2016
# 1      1/2/2016
# 2      1/3/2016
# 3      1/4/2016
# 4      1/5/2016
# 5      1/6/2016
# 6      1/7/2016
# 7      1/8/2016
# 8      1/9/2016
# 9     1/10/2016
# 10    1/11/2016
# 11    1/12/2016
# 12    1/13/2016
# 13    1/14/2016
# 14    1/15/2016
# 15    1/16/2016
# 16    1/17/2016
# 17    1/18/2016
# 18    1/19/2016
# 19    1/20/2016
# 20    1/21/2016
# 21    1/22/2016
# 22    1/23/2016
# 23    1/24/2016
# 24    1/25/2016
# 25    1/26/2016
# 26    1/27/2016
# 27    1/28/2016
# 28    1/29/2016
# 29    1/30/2016
# 30    1/31/2016
# Name: EST, dtype: object

# %%
df[['EST','Temperature']]
# Out:
#           EST  Temperature
# 0    1/1/2016           38
# 1    1/2/2016           36
# 2    1/3/2016           40
# 3    1/4/2016           25
# 4    1/5/2016           20
# 5    1/6/2016           33
# 6    1/7/2016           39
# 7    1/8/2016           39
# 8    1/9/2016           44
# 9   1/10/2016           50
# 10  1/11/2016           33
# 11  1/12/2016           35
# 12  1/13/2016           26
# 13  1/14/2016           30
# 14  1/15/2016           43
# 15  1/16/2016           47
# 16  1/17/2016           36
# 17  1/18/2016           25
# 18  1/19/2016           22
# 19  1/20/2016           32
# 20  1/21/2016           31
# 21  1/22/2016           26
# 22  1/23/2016           26
# 23  1/24/2016           28
# 24  1/25/2016           34
# 25  1/26/2016           43
# 26  1/27/2016           41
# 27  1/28/2016           37
# 28  1/29/2016           36
# 29  1/30/2016           34
# 30  1/31/2016           46

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df.Temperature.describe()
# Out:
# count    31.000000
# mean     34.677419
# std       7.639315
# min      20.000000
# 25%      29.000000
# 50%      35.000000
# 75%      39.500000
# max      50.000000
# Name: Temperature, dtype: float64

# %%
df[df.Temperature==df.Temperature.max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
df.EST[df.Temperature==df.Temperature.max()]
# Out:
# 9    1/10/2016
# Name: EST, dtype: object

# %%
#pip3 install xlrd
# df1=pd.read_excel("Path")

# %%
df.to_csv('new.csv',index=False)

# %%
#To excel openpyxl
#df1.to_excel("Path")

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df1=pd.read_csv("/Users/Suhas/Downloads/weather_data_cities.csv")
df1
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
a=df1.groupby('city')
for x,y in a:
    print(x)
    print(y)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
a.get_group('mumbai')
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
a.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
a.min()
# Out:
#                day  temperature  windspeed   event
# city
# mumbai    1/1/2017           85          5     Fog
# new york  1/1/2017           28          6    Rain
# paris     1/1/2017           42          8  Cloudy

# %%
df3=pd.DataFrame({
    "Name":['a','b','c'],
    "Age":[10,20,30],
    "some_log":[True,False,True]
})
df3
# Out:
#   Name  Age  some_log
# 0    a   10      True
# 1    b   20     False
# 2    c   30      True

# %%
df4=pd.DataFrame({
    "Name":['d','e','f'],
    "Age":[100,200,300],
    "some_log":[True,False,False]
})
df4
# Out:
#   Name  Age  some_log
# 0    d  100      True
# 1    e  200     False
# 2    f  300     False

# %%
df5=pd.concat([df3,df4])
df5
# Out:
#   Name  Age  some_log
# 0    a   10      True
# 1    b   20     False
# 2    c   30      True
# 0    d  100      True
# 1    e  200     False
# 2    f  300     False

# %%
df5=pd.concat([df3,df4],ignore_index=True)
df5
# Out:
#   Name  Age  some_log
# 0    a   10      True
# 1    b   20     False
# 2    c   30      True
# 3    d  100      True
# 4    e  200     False
# 5    f  300     False

# %%
df5=pd.concat([df3,df4],ignore_index=True , axis=1)
df5
# Out:
#    0   1      2  3    4      5
# 0  a  10   True  d  100   True
# 1  b  20  False  e  200  False
# 2  c  30   True  f  300  False

# %%
df6=pd.merge(df3,df4 ,on="Age")
df6
# Out:
# Empty DataFrame
# Columns: [Name_x, Age, some_log_x, Name_y, some_log_y]
# Index: []
